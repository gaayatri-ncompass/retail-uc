# %%
import pandas as pd

# %%
customer_df = pd.read_csv('../data_source/raw_files/inventory.csv')

customer_df.isnull().sum()

customer_df.dtypes
# Out:
# customer_id      object
# customer_name    object
# email            object
# phone            object
# address          object
# signup_date      object
# dtype: object
